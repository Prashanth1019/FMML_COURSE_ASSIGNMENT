# %% [markdown]
# <a href="https://colab.research.google.com/github/Prashanth1019/FMML_COURSE_ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-18 16:30:17--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   403MB/s    in 0.2s
#
# 2023-05-18 16:30:24 (403 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22167  1506.04000v1  Gaussian process (GP) models form a core part ...  stat
# 944    1604.05377v1  Customer temporal behavioral data was represen...  stat
# 22952  1711.08042v2  Most research on the interpretability of machi...  stat
# 35319  cs/0402013v1  The fixpoint completion fix(P) of a normal log...    cs
# 7737   1803.00502v2  In this paper, we present a theoretical framew...  stat
# ...             ...                                                ...   ...
# 13932  1608.03757v2  In this paper, we are concerned with a branch ...    cs
# 7600   1802.04617v1  While optimizing convex objective (loss) funct...  stat
# 13124  1610.06656v2  In this paper we present a new algorithm for c...  stat
# 22566  1701.01437v2  This workshop explores the interface between c...  stat
# 30166  1711.08189v1  An analysis of different techniques for recogn...    cs
#
#                                                    title  year  \
# 22167   MCMC for Variationally Sparse Gaussian Processes  2015
# 944    Churn analysis using deep convolutional neural...  2016
# 22952  "I know it when I see it". Visualization and I...  2017
# 35319  Corollaries on the fixpoint completion: studyi...  2004
# 7737   PIP Distance: A Unitary-invariant Metric for U...  2018
# ...                                                  ...   ...
# 13932  Student's t Distribution based Estimation of D...  2016
# 7600   Fast Global Convergence via Landscape of Empir...  2018
# 13124                 Single Pass PCA of Matrix Products  2016
# 22566  NIPS 2016 Workshop on Representation Learning ...  2017
# 30166  An Analysis of Scale Invariance in Object Dete...  2017
#
#                                                 keywords
# 22167  [probabilistic, considerable, attacking, effic...
# 944    [behavioral, represented, prediction, leveragi...
# 22952  [interpretability, development, interpretabili...
# 35319  [completion, transformation, completion, kanch...
# 7737   [theoretical, framework, understanding, embedd...
# ...                                                  ...
# 13932  [concerned, evolutionary, algorithms, estimati...
# 7600   [optimizing, objective, functions, powerhouse,...
# 13124  [algorithm, computing, approximation, straight...
# 22566  [interface, cognitive, neuroscience, reproduce...
# 30166  [different, techniques, recognizing, detecting...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22167    [probabilistic, considerable, attacking, effic...
# 944      [behavioral, represented, prediction, leveragi...
# 22952    [interpretability, development, interpretabili...
# 35319    [completion, transformation, completion, kanch...
# 7737     [theoretical, framework, understanding, embedd...
#                                ...
# 39451    [autonomous, cluttered, environments, challeng...
# 169      [mathematically, generalization, partially, re...
# 38096    [effective, multifaceted, exploratory, heterog...
# 5404     [separation, testified, literature, factorizat...
# 11944    [enhancement, difficulty, estimations, objecti...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8962 words.
# Out of those 4608 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d9220790-1c0f-495b-944a-049480a96116" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9220790-1c0f-495b-944a-049480a96116")) {                    Plotly.newPlot(                        "d9220790-1c0f-495b-944a-049480a96116",                        [{"x":["considerable","replicate","experiment","variationally","efficiently","variational","posterior","covariance","efficient","approximate","simultaneously","parameters","attacking","posteriors","addresses","otherwise","processes","available","parameter","probabilistic","approximation","likelihood","computations","classification","autoencoders","customers","architectures","unsupervised","represented","behavioral","convolutional","opportunities","prominent","conducted","understand","maximally","leveraging","supervised","performed","prediction","autoencoder","interpretation","consequence","deficiencies","visualization","structure","presupposes","regularization","distributed","development","representations","technical","intuitive","reduction","understanding","introduces","furthermore","interpretability","dimensionality","significant","transformation","concerning","corollaries","characterizing","completion","effortlessly","correspondence","coincides","semantics","integration","immediate","knowledge","operators","lifschitz","essentially","factorization","embeddings","distributional","fundamental","invariant","especially","performing","robustness","perturbation","preserving","equivalent","existence","explicitly","phenomena","including","theoretical","hypothesis","difference","selection","embedding","functionality","invariance","dimension","formulating","parametrization","framework","stability","demonstrate","empirical","observing","recovering","projected","algorithm","condition","complexity","dependence","extension","optimization","algorithms","iterative","projection","potential","independent","annotated","precision","biological","identifying","biomedical","evaluating","platforms","benchmarking","improvement","challenge","iterations","relationships","annotation","documents","annotators","extraction","information","aggregate","increases","reproduced","mechanical","crowdsourcing","traditionally","capturing","annotations","investigated","generating","computational","abstracts","sentiment","dictionaries","contributions","innovative","clustered","following","dictionary","researcher","clustering","buildings","formulation","estimated","automated","necessary","prerequisite","approximately","classical","simulation","reinforcement","commercial","formulate","rescheduling","formulations","management","decomposing","dissatisfaction","representative","residential","specifically","auxiliary","superposition","empirically","principle","financial","discovering","interactions","difficult","associated","instruments","inference","impossible","observations","performance","intuition","distinguish","architecture","connected","outperforms","recognition","discriminative","segmentations","combining","propagation"],"y":[50,2,63,0,143,58,39,24,380,116,115,240,3,6,55,16,95,313,120,148,107,57,38,485,21,9,107,149,71,9,396,9,14,79,82,8,51,200,120,232,35,62,20,6,33,371,0,78,80,105,248,40,35,102,169,68,168,22,54,236,64,16,4,13,26,3,24,2,97,55,8,361,45,3,22,49,82,30,92,65,117,67,84,13,50,79,38,67,26,242,154,59,52,169,111,7,30,51,5,2,552,29,569,169,19,13,29,735,64,211,17,63,293,582,90,56,142,134,72,75,39,69,13,66,31,7,125,156,28,63,55,63,10,123,718,18,43,3,10,11,19,46,68,53,106,292,5,45,18,46,10,16,84,54,2,127,5,100,58,95,78,8,38,105,74,92,19,54,2,19,51,9,3,47,3,160,28,3,62,48,10,31,73,140,105,3,207,16,68,904,18,35,245,70,264,352,104,16,111,72],"type":"bar"},{"x":["considerable","replicate","experiment","variationally","efficientl ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4608,), (4608, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7783333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Using</span> <span style='background-color:rgba(0, 255, 0, 0.5619047619047619);'>Description</span> <span style=''>Logics</span> <span style=''>for</span> <span style=''>RDF</span> <span style='background-color:rgba(0, 255, 0, 0.34265734265734255);'>Constraint</span> <span style=''>Checking</span> <span style=''>and</span> <span style=''>Closed</span> <span style=''>World</span> <span style='background-color:rgba(0, 255, 0, 0.6146788990825688);'>Recognition</span> <br/><br/><span style=''>RDF</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.5619047619047619);'>Description</span> <span style=''>Logics</span> <span style=''>work</span> <span style=''>in</span> <span style=''>an</span> <span style=''>open</span> <span style=''>world</span> <span style=''>setting</span> <span style=''>where</span> <span style=''>absence</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3210671573137074);'>information</span> <span style=''>is</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3210671573137074);'>information</span> <span style=''>about</span> <span style=''>absence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nevertheless</span> <span style='background-color:rgba(0, 255, 0, 0.5619047619047619);'>Description</span> <span style=''>Logic</span> <span style=''>axioms</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpreted</span> <span style=''>in</span> <span style=''>a</span> <span style=''>closed</span> <span style=''>world</span> <span style=''>setting</span> <span style=''>and</span> <span style=''>in</span> <span style=''>this</span> <span style=''>setting</span> <span style=''>they</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>for</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.34265734265734255);'>constraint</span> <span style=''>checking</span> <span style=''>and</span> <span style=''>closed</span> <span style=''>world</span> <span style='background-color:rgba(0, 255, 0, 0.6146788990825688);'>recognition</span> <span style=''>against</span> <span style='background-color:rgba(0, 255, 0, 0.3210671573137074);'>information</span> <span style=''>sources</span> <span style=''>When</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3210671573137074);'>information</span> <span style=''>sources</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressed</span> <span style=''>in</span> <span style=''>well</span> <span style=''>behaved</span> <span style=''>RDF</span> <span style=''>or</span> <span style=''>RDFS</span> <span style=''>(ie</span> <span style=''>RDF</span> <span style=''>graphs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpreted</span> <span style=''>in</span> <span style=''>the</span> <span style=''>RDF</span> <span style=''>or</span> <span style=''>RDFS</span> <span style=''>semantics)</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.34265734265734255);'>constraint</span> <span style=''>checking</span> <span style=''>and</span> <span style=''>closed</span> <span style=''>world</span> <span style='background-color:rgba(0, 255, 0, 0.6146788990825688);'>recognition</span> <span style=''>is</span> <span style=''>simple</span> <span style=''>to</span> <span style=''>describe</span> <span style=''>Further</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.34265734265734255);'>constraint</span> <span style=''>checking</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implemented</span> <span style=''>as</span> <span style=''>SPARQL</span> <span style=''>querying</span> <span style=''>and</span> <span style=''>thus</span> <span style='background-color:r ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Least</span> <span style=''>Square</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Autoencoder</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regularization</span> <br/><br/><span style=''>In</span> <span style=''>recent</span> <span style=''>years</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Variation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Autoencoders</span> <span style=''>have</span> <span style=''>become</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style=''>popular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>learning</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complicated</span> <span style=''>distributionsVariational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Autoencoder</span> <span style=''>(VAE)</span> <span style=''>provides</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reconstructive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>over</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>autoencoder</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>auto</span> <span style=''>enocders</span> <span style=''>make</span> <span style=''>better</span> <span style=''>approximaiton</span> <span style=''>than</span> <span style=''>MCMC</span> <span style=''>The</span> <span style=''>VAE</span> <span style=''>defines</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>process</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ancestral</span> <span style=''>sampling</span> <span style=''>through</span> <span style=''>a</span> <span style=''>cascade</span> <span style=''>of</span> <span style=''>hidden</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>layers</span> <span style=''>They</span> <span style=''>are</span> <span style=''>a</span> <span style=''>directed</span> <span style=''>graphic</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>autoencoder</span> <span style=''>is</span> <span style=''>trained</span> <span style=''>to</span> <span style=''>maximise</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>are</span> <span style=''>trying</span> <span style=''>maximise</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>and</span> <span style=''>also</span> <span style=''>at</span> <span style=''>the</span> <span style=''>same</span> <span style=''>time</span> <span style=''>we</span> <span style=''>are</span> <span style=''>trying</span> <span style=''>to</span> <span style=''>make</span> <span style=''>a</span> <span style=''>good</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>Its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>basically</span> <span style=''>trading</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Partial</span> <span style=''>Order</span> <span style=''>MCMC</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structure</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Discovery</span> <span style=''>in</span> <span style=''>Bayesian</span> <span style=''>Networks</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>Markov</span> <span style=''>chain</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3160621761658031);'>estimating</span> <span style='background-color:rgba(255, 0, 0, 0.5958549222797926);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structural</span> <span style=''>features</span> <span style=''>in</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>The</span> <span style=''>method</span> <span style=''>draws</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5958549222797926);'>posterior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>partial</span> <span style=''>orders</span> <span style=''>on</span> <span style=''>the</span> <span style=''>nodes</span> <span style=''>for</span> <span style=''>each</span> <span style=''>sampled</span> <span style=''>partial</span> <span style=''>order</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>are</span> <span style=''>computed</span> <span style=''>exactly</span> <span style=''>We</span> <span style=''>give</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analytical</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>results</span> <span style=''>that</span> <span style=''>suggest</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>superiority</span> <span style=''>of</span> <span style=''>the</span> <span style=''>new</span> <span style=''>method</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>previous</span> <span style=''>methods</span> <span style=''>which</span> <span style=''>sample</span> <span style=''>either</span> <span style=''>directed</span> <span style=''>acyclic</span> <span style=''>graphs</span> <span style=''>or</span> <span style=''>linear</span> <span style=''>orders</span> <span style=''>on</span> <span style=''>the</span> <span style=''>nodes</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Maximum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Likelihood</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Random</span> <span style=''>Subspace</span> <span style=''>EDA</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Application</span> <span style=''>to</span> <span style=''>Extrasolar</span> <span style=''>Planet</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Detection</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>addresses</span> <span style=''>maximum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>(ML)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>based</span> <span style=''>model</span> <span style=''>fitting</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>extrasolar</span> <span style=''>planet</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>This</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>featured</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>following</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>1)</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>candidate</span> <span style=''>models</span> <span style=''>under</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consideration</span> <span style=''>are</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>2)</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>surface</span> <span style=''>has</span> <span style=''>a</span> <span style=''>huge</span> <span style=''>number</span> <span style=''>of</span> <span style=''>peaks</span> <span style=''>3)</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>space</span> <span style=''>ranges</span> <span style=''>in</span> <span style=''>size</span> <span style=''>from</span> <span style=''>a</span> <span style=''>few</span> <span style=''>to</span> <span style=''>dozens</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensions</span> <span style=''>These</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>make</span> <span style=''>the</span> <span style=''>ML</span> <span style=''>search</span> <span style=''>a</span> <span style=''>very</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>problem</span> <span style=''>as</span> <span style=''>it</span> <span style=''>lacks</span> <span style=''>any</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analytical</span> <span style=''>or</span> <span style=''>gradient</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>searching</span> <span style=''>solution</span> <span style=''>to</span> <span style=''>explore</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>space</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>population</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>searching</span> <span style=''>method</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style='background-color:rgba ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10582386363636363)
# 	experimental (0.13671875)
# 	architecture (0.08700284090909091)
# 	segmentation (0.08025568181818182)
# 	knowledge (0.12819602272727273)
# 	detection (0.11931818181818182)
# 	information (0.2549715909090909)
# 	different (0.2610085227272727)
# 	recognition (0.125)
# 	convolutional (0.140625)
#
# Some Statistics words are:
# 	optimization (0.19657258064516128)
# 	estimation (0.17137096774193547)
# 	variables (0.14516129032258066)
# 	statistical (0.1592741935483871)
# 	theoretical (0.15776209677419356)
# 	distribution (0.18245967741935484)
# 	inference (0.19153225806451613)
# 	dimensional (0.1849798387096774)
# 	algorithm (0.3966733870967742)
# 	regression (0.18245967741935484)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5392e790-d0e3-4c1e-91ec-52ca4e0825ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5392e790-d0e3-4c1e-91ec-52ca4e0825ec")) {                    Plotly.newPlot(                        "5392e790-d0e3-4c1e-91ec-52ca4e0825ec",                        [{"x":["considerable","replicate","experiment","variationally","efficiently","variational","posterior","covariance","efficient","approximate","simultaneously","parameters","attacking","posteriors","addresses","otherwise","processes","available","parameter","probabilistic","approximation","likelihood","computations","classification","autoencoders","customers","architectures","unsupervised","represented","behavioral","convolutional","opportunities","prominent","conducted","understand","maximally","leveraging","supervised","performed","prediction","autoencoder","interpretation","consequence","deficiencies","visualization","structure","presupposes","regularization","distributed","development","representations","technical","intuitive","reduction","understanding","introduces","furthermore","interpretability","dimensionality","significant","transformation","concerning","corollaries","characterizing","completion","effortlessly","correspondence","coincides","semantics","integration","immediate","knowledge","operators","lifschitz","essentially","factorization","embeddings","distributional","fundamental","invariant","especially","performing","robustness","perturbation","preserving","equivalent","existence","explicitly","phenomena","including","theoretical","hypothesis","difference","selection","embedding","functionality","invariance","dimension","formulating","parametrization","framework","stability","demonstrate","empirical","observing","recovering","projected","algorithm","condition","complexity","dependence","extension","optimization","algorithms","iterative","projection","potential","independent","annotated","precision","biological","identifying","biomedical","evaluating","platforms","benchmarking","improvement","challenge","iterations","relationships","annotation","documents","annotators","extraction","information","aggregate","increases","reproduced","mechanical","crowdsourcing","traditionally","capturing","annotations","investigated","generating","computational","abstracts","sentiment","dictionaries","contributions","innovative","clustered","following","dictionary","researcher","clustering","buildings","formulation","estimated","automated","necessary","prerequisite","approximately","classical","simulation","reinforcement","commercial","formulate","rescheduling","formulations","management","decomposing","dissatisfaction","representative","residential","specifically","auxiliary","superposition","empirically","principle","financial","discovering","interactions","difficult","associated","instruments","inference","impossible","observations","performance","intuition","distinguish","architecture","connected","outperforms","recognition","discriminative","segmentations","combining","propagation","approaches","renormalization","segmentation","conventional","concentration","optimistic","guarantees","distributions","extensive","dimensional","demonstrated","optimality","inequality","divergence","parametric","exponential","bernoulli","asymptotic","expression","correlated","encouraging","particular","important","metabolite","formulated","interesting","rotational","regression","paramount","additionally","correlation","assumption","simulations","structured","importance","hyperparameter","emphlatent","measurement","introduce","unobserved","explaining","experiments","shrinkage","macroeconomic","variables","unidentifiability","modelling","affecting","therefore","assumptions","statistics","methodology","distributio ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	variationally
# 	presupposes
# 	metabolite
# 	macroeconomic
# 	eigenmaps
# 	stationarities
# 	schizophrenia
# 	portraits
# 	criminology
# 	pediatric
# 	physiologic
# 	resampled
# 	spectroradiometer
# 	degeneration
# 	manufacturability
# 	deflation
# 	conformalized
# 	conformal
# 	percolation
# 	terabytes
# Some words which never appear in Statistics papers:
# 	effortlessly
# 	lifschitz
# 	reproduced
# 	rescheduling
# 	dissatisfaction
# 	residential
# 	dynamique
# 	evolutions
# 	demosaicing
# 	deblurring
# 	transferrable
# 	reordering
# 	isolating
# 	illumination
# 	concretely
# 	egocentric
# 	comparator
# 	shortcuts
# 	undecidable
# 	decidable

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0517578125e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7308333333333333
